# %% [markdown]
# # Student Score Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

data = pd.read_csv("student.csv")

# correct X and y
X = data[['Hours']]     # 2D
y = data['Scores']      #1d

model = LinearRegression()
model.fit(X, y)

pred = model.predict(X)

# evaluate
mae = mean_absolute_error(y, pred)
mse = mean_squared_error(y, pred)
rmse = np.sqrt(mse)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)

# prediction for 7 hours
prediction = model.predict([[7]])
print("The student score after studying 7 hours is:", prediction[0])
# Out:
# MAE: 0.6666666666666643
# MSE: 0.6285714285714282
# RMSE: 0.7928249671720916
# The student score after studying 7 hours is: 86.4
# c:\Users\gopal ghosh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
